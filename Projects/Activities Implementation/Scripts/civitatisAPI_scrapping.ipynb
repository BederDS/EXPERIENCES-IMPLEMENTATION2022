# %%
import numpy as np
import pandas as pd
import pandas.io.sql as sql
import pymysql
import thefuzz
import xlwt
import sqlalchemy
import time
import civitatisAPI as civi
import requests
import json

from requests.auth import HTTPBasicAuth
from thefuzz import fuzz
from thefuzz import process
from sqlalchemy import create_engine
from pymysql import*
from IPython.display import clear_output
# Out:
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\thefuzz\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
## Source cPanel
user= 'beder'
password="DEjUYJjxfRSvab3T"
host="server.digizonelabs.com"
databases_schema = []

con=connect(user="beder",password="DEjUYJjxfRSvab3T",host="server.digizonelabs.com",database="beder_appprod")

posts=sql.read_sql('select * from beder_appprod.post',con)
place=sql.read_sql('select * from beder_appprod.place',con)
# Out:
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
countries=sql.read_sql('select * from beder_appprod.countries',con)
regions=sql.read_sql('select * from beder_appprod.regions',con)
provinces=sql.read_sql('select * from beder_appprod.provinces',con)
cities=sql.read_sql('select * from beder_appprod.cities',con)
# Out:
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\beder\.conda\envs\ACTIMPLEMENTATION2022\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
all_destinations_df = pd.read_csv('C:\\Users\\beder\Desktop\Data 2022\Projects\Activities Implementation\Outputs\Civitatis Exctraction\\all_destinations21_07_2022.csv')
all_destinations_df.rename(columns = {'id':'destinationId'}, inplace = True)
all_destinations_df.sample(3)
# Out:
#       destinationId  countryId     name  hasTransfers  hasActivities  \
# 3081           3292        203     Ella         False           True
# 1845           3033         82  Épernay         False           True
# 595            3260         72    Piran         False           True
#
#                                                  photos
# 3081  {'header': [{'caption': 'Ella', 'paths': {'ori...
# 1845  {'header': [{'caption': 'Épernay', 'paths': {'...
# 595   {'header': [{'caption': 'Piran', 'paths': {'or...

# %%
all_activities_df = pd.read_csv('C:\\Users\\beder\Desktop\Data 2022\Projects\Activities Implementation\Outputs\Civitatis Exctraction\\all_activities21_07_2022.csv')
all_activities_df.sample(3)
# Out:
#       id  isoNum ISO2 ISO3  travelInsurance                            nombre  \
# 188  192     670   VC  VCT            False  Saint Vincent and the Grenadines
# 40    42     124   CA  CAN            False                            Canada
# 189  193     654   SH  SHN            False                      Saint Helena
#
#                                  name  \
# 188  Saint Vincent and the Grenadines
# 40                             Canada
# 189                      Saint Helena
#
#                                                 photos
# 188  {'header': [{'caption': 'Saint Vincent and the...
# 40   {'header': [{'caption': 'Canada', 'paths': {'o...
# 189  {'header': [{'caption': 'Saint Helena', 'paths...

# %%
pd.merge(all_destinations_df,all_activities_df, on )

# %% [markdown]
# # Borrar

# %%
usr = 'bederapp'
pss ='w5OWhwNPL1tU'
lnag = 'en'
session = civi.Civitatis(username=usr,password=pss)

# %%
civitatis_countries = session.get_countries('en')
civitatis_countries_df = pd.DataFrame(civitatis_countries)

# %%
civitatis_countries_df
# Out:
#       id  isoNum ISO2 ISO3  travelInsurance         nombre           name  \
# 0      1       4   AF  AFG            False    Afghanistan    Afghanistan
# 1      2     248   AX  ALA            False  Åland Islands  Åland Islands
# 2      3       8   AL  ALB            False        Albania        Albania
# 3      4     276   DE  DEU             True        Germany        Germany
# 4      5      20   AD  AND            False        Andorra        Andorra
# ..   ...     ...  ...  ...              ...            ...            ...
# 237  241     499   ME  MNE            False     Montenegro     Montenegro
# 238  259       0   BT  064            False         Bhutan         Bhutan
# 239  262     530   AN  ANT            False        Curazao        Curazao
# 240  276     535   BQ  BES            False        Bonaire        Bonaire
# 241  280       0   BL   BL            False  San Bartolomé  San Bartolomé
#
#                                                 photos
# 0    {'header': [{'caption': 'Afghanistan', 'paths'...
# 1    {'header': [{'caption': 'Åland Islands', 'path...
# 2    {'header': [{'caption': 'Albania', 'paths': {'...
# 3    {'header': [{'caption': 'Germany', 'paths': {'...
# 4    {'header': [{'caption': 'Andorra', 'paths': {'...
# ..                                                 ...
# 237  {'header': [{'caption': 'Montenegro', 'paths':...
# 238  {'header': [{'caption': 'Bhutan', 'paths': {'o...
# 239  {'header': [{'caption': 'Curazao', 'paths': {'...
# 240  {'header': [{'caption': 'Bonaire', 'paths': {'...
# 241  {'header': [{'caption': 'San Bartolomé', 'path...
#
# [242 rows x 8 columns]

# %%
print(countries.shape,civitatis_countries_df.shape)
# Out:
# (236, 28) (242, 8)

# %%
#Take only the important columns of the countries table

countries =  countries[['country_id', 'google_id', 'english_name',
       'spanish_name']]

# %%
civitatis_countries = civitatis_countries_df['name'].unique()
countries_col = countries['english_name'].unique()
dic_replace = {}
for country in civitatis_countries:
    matches = process.extractOne(country, countries_col)
    if  90 <= matches[1] <100:
        dic_replace[country] = matches[0]

civitatis_countries_df['name'] = civitatis_countries_df['name'].replace(dic_replace, regex=True)

# %%
civitatis_countries = civitatis_countries_df['name'].unique()
countries_col = countries['english_name'].unique()
dic_replace = {}
for country in civitatis_countries:
    matches = process.extractOne(country, countries_col)
    if  matches[1] <90:
        print(country,matches)
        #dic_replace[country] = matches[0]
# Out:
# Åland Islands ('British Virgin Islands', 86)
# Antarctica ('Qatar', 72)
# Bermudas ('Peru', 68)
# Bouvet Island ('Iceland', 69)
# Christmas Island ('Cayman Islands', 67)
# Cocos Island ('Cook Islands', 83)
# Heard Island and the McDonald Islands ('Faroe Islands', 86)
# Libya ('Libye', 80)
# Moldavia ('Latvia', 71)
# Norfolk Island ('Cook Islands', 77)
# United Kingdom  ('Niue', 68)
# Western Sahara ('Aruba', 68)
# Svalbard and Jan Mayen ('South Georgia and the South Sandwich Islands', 86)
# French Southern and Antarctic Lands ('Bosnia and Herzegovina', 86)
# Tokelau ('Belarus', 57)
# Bonaire ('Niue', 55)
# San Bartolomé ('Saint Barthélemy', 74)

# %%
dic_replace = {'San Bartolomé':'Saint Barthélemy'}
civitatis_countries_df['name'] = civitatis_countries_df['name'].replace(dic_replace, regex=True)

# %%
initial_merge = pd.merge(countries,civitatis_countries_df,how='left', left_on='english_name',right_on='name')
completed = initial_merge[initial_merge['name'].notna()]
completed.sample(10)
# Out:
#      country_id                    google_id           english_name  \
# 153         156  ChIJjcVRlmGICw0Rw_8sxIGT09k                Morocco
# 115         117  ChIJTaCxWbmcwW8RLhIHB2hUZ48                 Tuvalu
# 175         178  ChIJ4aQWg0SVVRIR75sBqjozhDo                Tunisia
# 96           98  ChIJDXKKxm4ZEowR6IYdmsaa6d4  Saint Kitts and Nevis
# 187         190  ChIJp4vhgO2qrTARa_zhxOAoLQ8             Bangladesh
# 18           19  ChIJVU1JymcX3hQRbhTEf4A8TDI                 Cyprus
# 154         157  ChIJyXRE-U1QfCERMdBrEcLZA0I              Mauritius
# 168         171  ChIJg1vR7KcuHRgRvuXpXM46OZ4                Somalia
# 1             2  ChIJ_UuggpyUkkYRwyW0T7qf6kA                Estonia
# 25           27  ChIJa76xwh5ymkcRW-WRjmtd6HU                Germany
#
#             spanish_name     id  isoNum ISO2 ISO3 travelInsurance  \
# 153            Marruecos  140.0   504.0   MA  MAR            True
# 115               Tuvalu  226.0   798.0   TV  TUV           False
# 175                Túnez  222.0   788.0   TN  TUN            True
# 96   Saint Kitts y Nevis  189.0   659.0   KN  KNA           False
# 187           Bangladesh   21.0    50.0   BD  BGD           False
# 18                Chipre   48.0   196.0   CY  CYP           False
# 154             Mauricio  143.0   480.0   MU  MUS            True
# 168              Somalia  202.0   706.0   SO  SOM           False
# 1                Estonia   76.0   233.0   EE  EST           False
# 25              Alemania    4.0   276.0   DE  DEU            True
#
#                     nombre                   name  \
# 153                Morocco                Morocco
# 115                 Tuvalu                 Tuvalu
# 175                Tunisia                Tunisia
# 96   Saint Kitts and Nevis  Saint Kitts and Nevis
# 187             Bangladesh             Bangladesh
# 18                  Cyprus                 Cyprus
# 154              Mauritius              Mauritius
# 168                Somalia                Somalia
# 1                  Estonia                Estonia
# 25                 Germany                Germany
#
#                                                 photos
# 153  {'header': [{'caption': 'Morocco', 'paths': {'...
# 115  {'header': [{'caption': 'Tuvalu', 'paths': {'o...
# 175  {'header': [{'caption': 'Tunisia', 'paths': {'...
# 96   {'header': [{'caption': 'Saint Kitts and Nevis...
# 187  {'header': [{'caption': 'Bangladesh', 'paths':...
# 18   {'header': [{'caption': 'Cyprus', 'paths': {'o...
# 154  {'header': [{'caption': 'Mauritius', 'paths': ...
# 168  {'header': [{'caption': 'Somalia', 'paths': {'...
# 1    {'header': [{'caption': 'Estonia', 'paths': {'...
# 25   {'header': [{'caption': 'Germany', 'paths': {'...

# %%
completed_dic = dict(zip(completed['country_id'],completed['id']))

# %%
manual_match = {18.0:148.0,\
    20.0:180.0,\
    45.0:24.0,\
    51.0:180.0,
    52.0:180.0,
    53.0:180.0,
    90.0:276.0,
    105.0: 164.0,
    152.0:126.0,
    165.0:54.0,
    173.0:205.0,
    219.0: 167.0,
    221.0:201.0}
manual_match
# Out:
# {18.0: 148.0,
#  20.0: 180.0,
#  45.0: 24.0,
#  51.0: 180.0,
#  52.0: 180.0,
#  53.0: 180.0,
#  90.0: 276.0,
#  105.0: 164.0,
#  152.0: 126.0,
#  165.0: 54.0,
#  173.0: 205.0,
#  219.0: 167.0,
#  221.0: 201.0}

# %%
completed_dic.update(manual_match)
completed_df = pd.DataFrame.from_dict(completed_dic,orient='index')
completed_df = completed_df.reset_index()
completed_df
# Out:
#      index      0
# 0      1.0   73.0
# 1      2.0   76.0
# 2      3.0  123.0
# 3      4.0  128.0
# 4      5.0   80.0
# ..     ...    ...
# 226  152.0  126.0
# 227  165.0   54.0
# 228  173.0  205.0
# 229  219.0  167.0
# 230  221.0  201.0
#
# [231 rows x 2 columns]

# %%
countries= pd.merge(countries,completed_df, how = 'left', left_on='country_id',right_on='index')

# %%
countries.drop(['index'],axis= 1)
countries.rename(columns = {0:'id'}, inplace = True)

# %%
countries= countries.drop(['index'],axis= 1)

# %%
countries_merged = pd.merge(countries,civitatis_countries_df,how='left', on ='id')
countries_merged[countries_merged['name'].isna()]
# Out:
#      country_id                    google_id  english_name   spanish_name  id  \
# 11           12  ChIJ97NxcaPC6kAR67r_KuAJbyo        Crimea         Crimea NaN
# 20           21  ChIJNb4UJ3a_DA0RD4cANiYlTjg     Gibraltar      Gibraltar NaN
# 98          101  ChIJw5D41mJuDowRQo8zJsIsi3I  Sint Maarten   Sint Maarten NaN
# 171         175  ChIJGTE-PbUwGRcRl7y2fmND8Ns   South Sudan  Sudán del Sur NaN
# 235         240  ChIJV9ZNUQlAUxMR9svXjuodG7c        Kosovo         Kosovo NaN
#
#      isoNum ISO2 ISO3 travelInsurance nombre name photos
# 11      NaN  NaN  NaN             NaN    NaN  NaN    NaN
# 20      NaN  NaN  NaN             NaN    NaN  NaN    NaN
# 98      NaN  NaN  NaN             NaN    NaN  NaN    NaN
# 171     NaN  NaN  NaN             NaN    NaN  NaN    NaN
# 235     NaN  NaN  NaN             NaN    NaN  NaN    NaN

# %% [markdown]
# # ATTEMPT TO EXTRACT MEXICO

# %%
countries_merged[countries_merged['name'] == 'Mexico']
# Out:
#     country_id                    google_id english_name spanish_name     id  \
# 53          56  ChIJU1NoiDs6BIQREZgJa760ZO0       Mexico       México  146.0
#
#     isoNum ISO2 ISO3 travelInsurance  nombre    name  \
# 53   484.0   MX  MEX            True  Mexico  Mexico
#
#                                                photos
# 53  {'header': [{'caption': 'Mexico', 'paths': {'o...

# %%
#first extract all destinations in Mexico
destinations_mexico=session.get_country_destinations(146,'en')
destinations_mexico_df = pd.DataFrame(destinations_mexico)
destinations_mexico_df.sample(10)
# Out:
#       id  countryId              name  hasTransfers  hasActivities  \
# 43  3000        146            Colima         False           True
# 30  2038        146          Ensenada         False           True
# 63  4055        146         Frontera          False           True
# 24  1075        146        Valladolid         False           True
# 21   805        146           Bacalar          True           True
# 25  1774        146           Cozumel         False           True
# 64  4080        146         Chetumal           True           True
# 88  4714        146        Manzanillo         False           True
# 89  4757        146  Villa del Carbón         False           True
# 28  1947        146     Ciudad Valles         False           True
#
#                                                photos
# 43  {'header': [{'caption': 'Colima', 'paths': {'o...
# 30  {'header': [{'caption': 'Ensenada', 'paths': {...
# 63  {'header': [{'caption': 'Frontera ', 'paths': ...
# 24  {'header': [{'caption': 'Valladolid', 'paths':...
# 21  {'header': [{'caption': 'Bacalar', 'paths': {'...
# 25  {'header': [{'caption': 'Cozumel', 'paths': {'...
# 64  {'header': [{'caption': 'Chetumal ', 'paths': ...
# 88  {'header': [{'caption': 'Manzanillo', 'paths':...
# 89  {'header': [{'caption': 'Villa del Carbón', 'p...
# 28  {'header': [{'caption': 'Ciudad Valles', 'path...

# %%
#Extract from one particular destination
bacalar_act = session.get_destination_activities(4080,'en')
bacalar_act_df = pd.DataFrame(bacalar_act)

# %% [markdown]
# # Design function to exctract everything in civitatis

# %%
civitatis_countries = session.get_countries('en')

# %%
civitatis_countries = session.get_countries('en')

countries_dic = {}
for entry in civitatis_countries:
    countries_dic[entry['name']]=entry['id']

frames = []
for country_id in countries_dic.values():
    clear_output(wait=True)
    print(country_id,len(countries_dic.values()),flush=True)
    frames.append(pd.DataFrame(session.get_country_destinations(country_id,'en')))

print('countries done',flush=True)
all_destinations_df =  pd.concat(frames)

acti_frames= []
for i, acti_id  in enumerate(all_destinations_df['id']):
    clear_output(wait=True)
    print(acti_id,i,len(all_destinations_df['id']),flush=True)
    acti_frames.append(pd.DataFrame(session.get_destination_activities(acti_id,'en')))

print('activities done')
all_activities = pd.concat(acti_frames)
# Out:
# 3765 3226 3227
# activities done

# %%
all_activities = pd.concat(acti_frames)

# %%
all_destinations_df[all_destinations_df['name'] == '']
# Out:
#       id  countryId              name  hasTransfers  hasActivities  \
# 65  4218        146  Playa del Carmen          True           True
#
#                                                photos
# 65  {'header': [{'caption': 'Playa del Carmen', 'p...

# %%
all_activities['minimumPrice']
# Out:
# 0    55.0
# 1    45.0
# 2    80.0
# 0    50.0
# 1    30.0
#      ...
# 4    29.0
# 5    49.0
# 6    19.0
# 0    48.0
# 1    37.5
# Name: minimumPrice, Length: 14558, dtype: float64

# %%
all_activities.sample(10)
# Out:
#         id  type  destinationId  \
# 36    6519     1           4320
# 32   68353     1            120
# 4    63604     1            312
# 8    29046     1           4208
# 4    89372     1           1093
# 43   14965     1              2
# 6    62431     2            270
# 3   133271     2           4281
# 0   138872     2           3219
# 3   142043     1           4632
#
#                                              title  voucherType  \
# 36  Excursion to Timanfaya and the Jameos del Agua            0
# 32                          Medieval Valencia Tour            0
# 4                       Punta Umbria Sunset Cruise            0
# 8                 Mdina and Dingli Cliffs Day trip            0
# 4                       Icelandic Lava Show in Vík            0
# 43                                Segovia Day Trip            0
# 6                             Salerno Private Tour            0
# 3                          Tweed Heads Boat Rental            0
# 0               Boat Hire with Skipper in Maafushi            0
# 3            Columbia River & Multnomah Falls Tour            0
#
#                                     relatedActivities  score  reviews  \
# 36  [{'id': 1648, 'lang': 'es'}, {'id': 7145, 'lan...   8.61      507
# 32  [{'id': 9460, 'lang': 'es'}, {'id': 20398, 'la...   9.80       10
# 4   [{'id': 59770, 'lang': 'es'}, {'id': 60793, 'l...   9.79       19
# 8   [{'id': 16723, 'lang': 'es'}, {'id': 18361, 'l...   8.09      177
# 4   [{'id': 27124, 'lang': 'es'}, {'id': 89585, 'l...   7.33        3
# 43  [{'id': 12529, 'lang': 'es'}, {'id': 16006, 'l...   7.80      167
# 6   [{'id': 3507, 'lang': 'es'}, {'id': 62485, 'la...   0.00        1
# 3   [{'id': 133270, 'lang': 'es'}, {'id': 133272, ...   0.00        1
# 0   [{'id': 138870, 'lang': 'es'}, {'id': 138873, ...   0.00        1
# 3   [{'id': 142042, 'lang': 'es'}, {'id': 142044, ...   0.00        1
#
#                                                   url  \
# 36  https://www.civitatis.com/en/arrecife/timanfay...
# 32  https://www.civitatis.com/en/valencia/medieval...
# 4   https://www.civitatis.com/en/el-rompido/punta-...
# 8   https://www.civitatis.com/en/sliema/mdina-ding...
# 4   https://www.civitatis.com/en/vik/icelandic-lav...
# 43  https://www.civitatis.com/en/madrid/excursion-...
# 6   https://www.civitatis.com/en/salerno/walking-tour
# 3   https://www.civitatis.com/en/tweed-heads/boat-...
# 0   https://www.civitatis.com/en/maafushi/boat-hir...
# 3   https://www.civitatis.com/en/portland/columbia...
#
#                                           description  ...        notIncluded  \
# 36  Discover incredible volcanic landscapes with t...  ...  [Food and drink.]
# 32  Discover the historic <b>silk exchange, the ma...  ...                 []
# 4   Discover the Huelva estuary with this <b>fabul...  ...                 []
# 8   The <b>walled city of Mdina</b> is one of the ...  ...                 []
# 4   Immerse yourself in the natural phenomena of t...  ...                 []
# 43  <b>Segovia is one of 15 Spanish cities declare...  ...                 []
# 6   Discover one of the most beautiful medieval ci...  ...          [Tickets]
# 3   <p>Enjoy the waters of Tweed Heads in a unique...  ...   [Food and drink]
# 0   When you hire your boat with a skipper in Maaf...  ...                 []
# 3   Trace the legacy of the historic&nbsp;Lewis an...  ...                 []
#
#    cancelPolicy                                    cancelPolicies  \
# 36               [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
# 32                [{'hours': 1, 'penalty': 0, 'type': 'percent'}]
# 4                [{'hours': 72, 'penalty': 0, 'type': 'percent'}]
# 8                [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
# 4                [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
# 43               [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
# 6                [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
# 3                [{'hours': 48, 'penalty': 0, 'type': 'percent'}]
# 0                [{'hours': 48, 'penalty': 0, 'type': 'percent'}]
# 3                [{'hours': 24, 'penalty': 0, 'type': 'percent'}]
#
#     MinimumPaxPerBooking                                        infoVoucher  \
# 36                   NaN  <p>Before the day of the excursion, the local ...
# 32                   NaN  <p>At the scheduled time, the local tour guide...
# 4                   None  <h2>Tour with pickup</h2>\n\n<p>At the indicat...
# 8                   None  <p>The tour includes pick up between<strong> 8...
# 4                      1  <p>We recommed being at the <strong>Icelandic ...
# 43                   NaN  <p>Please be waiting 10 minutes before the ind...
# 6                    NaN  <p>We'll meet at your chosen time at&nbsp;<str...
# 3                      1  <p>On the day of the activity, you must be at ...
# 0                    1.0  <p>On the day of the activity, we'll pick you ...
# 3                      1  <p>We'll meet at the scheduled time at the&nbs...
#
#                                      duration  \
# 36    {'min': 600, 'max': 0, 'duration': 600}
# 32    {'min': 150, 'max': 0, 'duration': 150}
# 4       {'min': 90, 'max': 0, 'duration': 90}
# 8   {'min': 270, 'max': 510, 'duration': 510}
# 4       {'min': 40, 'max': 0, 'duration': 40}
# 43  {'min': 300, 'max': 660, 'duration': 660}
# 6     {'min': 120, 'max': 0, 'duration': 120}
# 3     {'min': 420, 'max': 0, 'duration': 420}
# 0     {'min': 390, 'max': 0, 'duration': 390}
# 3     {'min': 120, 'max': 0, 'duration': 120}
#
#                                               advance  \
# 36  {'days': 1, 'hour': '13:00', 'minutes_before':...
# 32    {'days': 0, 'hour': None, 'minutes_before': 30}
# 4   {'days': 0, 'hour': None, 'minutes_before': 1440}
# 8    {'days': 0, 'hour': None, 'minutes_before': 720}
# 4   {'days': 0, 'hour': None, 'minutes_before': None}
# 43  {'days': 0, 'hour': '08:00', 'minutes_before':...
# 6   {'days': 0, 'hour': None, 'minutes_before': 1800}
# 3   {'days': 0, 'hour': None, 'minutes_before': None}
# 0   {'days': 0, 'hour': None, 'minutes_before': None}
# 3   {'days': 0, 'hour': None, 'minutes_before': None}
#
#                                               address  \
# 36  {'address': '', 'shortAddress': '', 'latitude'...
# 32  {'address': '', 'shortAddress': 'Plaza de la V...
# 4   {'address': '', 'shortAddress': '', 'latitude'...
# 8   {'address': '', 'shortAddress': '', 'latitude'...
# 4   {'address': '', 'shortAddress': 'Víkurbraut, 5...
# 43  {'address': '', 'shortAddress': 'Calle Ferraz,...
# 6   {'address': '', 'shortAddress': 'Piazza Matteo...
# 3   {'address': '', 'shortAddress': '2 River Terra...
# 0   {'address': '', 'shortAddress': '', 'latitude'...
# 3   {'address': '', 'shortAddress': 'Benson Hotel ...
#
#                                         accessibility  \
# 36  {'code': 200, 'description': 'No, not suitable...
# 32  {'code': 200, 'description': 'No, not suitable...
# 4   {'code': 200, 'description': 'No, not suitable...
# 8   {'code': 200, 'description': 'No, not suitable...
# 4   {'code': 200, 'description': 'No, not suitable...
# 43  {'code': 200, 'description': 'No, not suitable...
# 6   {'code': 200, 'description': 'No, not suitable...
# 3                    {'code': 0, 'description': None}
# 0                    {'code': 0, 'description': None}
# 3                    {'code': 0, 'description': None}
#
#                                                 rates
# 36  [{'id': 0, 'text': '(Gran Tour)General', 'cate...
# 32  [{'id': 0, 'text': 'Tour in English', 'categor...
# 4   [{'id': 0, 'text': 'Tour with pickup', 'catego...
# 8   [{'id': 0, 'text': 'Half-Day Excursion', 'cate...
# 4   [{'id': 0, 'text': 'Icelandic lava show', 'cat...
# 43  [{'id': 0, 'text': 'Half day in Segovia leavin...
# 6   [{'id': 0, 'text': 'Private tour in English', ...
# 3   [{'id': 0, 'text': 'Boat rental', 'categories'...
# 0   [{'id': 0, 'text': 'Vaavu Atoll Boat Trip', 'c...
# 3   [{'id': 0, 'text': 'General', 'categories': [{...
#
# [10 rows x 28 columns]

# %%
all_activities[['title','minimumPrice','originalPrice']].sample(10)
# Out:
#                                           title  minimumPrice  originalPrice
# 2                      Potosí Private Day Trips         267.0          267.0
# 13                       Asuncion Shopping Tour      562500.0       562500.0
# 15                          Huatulco Bay Cruise         451.2          480.0
# 4         Cappadocia: Cavusin and Kaymakli Tour          65.0           65.0
# 5                   Wine Tour of South Tenerife          79.0           79.0
# 5   Museum of Memory and Human Rights Free Tour           0.0            0.0
# 11             Coimbra Jewish Quarter Free Tour           0.0            0.0
# 8          Mysteries and Legends Tour of Orosei          15.0           15.0
# 0                      Ashram Tour of Rishikesh         800.0          800.0
# 7                   Private Day Trip from Lagos         300.0          300.0

# %%
all_activities[all_activities['id']==68353]
# Out:
#        id  type  destinationId                   title  voucherType  \
# 32  68353     1            120  Medieval Valencia Tour            0
#
#                                     relatedActivities  score  reviews  \
# 32  [{'id': 9460, 'lang': 'es'}, {'id': 20398, 'la...    9.8       10
#
#                                                   url  \
# 32  https://www.civitatis.com/en/valencia/medieval...
#
#                                           description  ... notIncluded  \
# 32  Discover the historic <b>silk exchange, the ma...  ...          []
#
#    cancelPolicy                                   cancelPolicies  \
# 32               [{'hours': 1, 'penalty': 0, 'type': 'percent'}]
#
#     MinimumPaxPerBooking                                        infoVoucher  \
# 32                   NaN  <p>At the scheduled time, the local tour guide...
#
#                                    duration  \
# 32  {'min': 150, 'max': 0, 'duration': 150}
#
#                                             advance  \
# 32  {'days': 0, 'hour': None, 'minutes_before': 30}
#
#                                               address  \
# 32  {'address': '', 'shortAddress': 'Plaza de la V...
#
#                                         accessibility  \
# 32  {'code': 200, 'description': 'No, not suitable...
#
#                                                 rates
# 32  [{'id': 0, 'text': 'Tour in English', 'categor...
#
# [1 rows x 28 columns]

# %%
civitatis_countries = session.get_countries('en')
civitatis_countries_df = pd.DataFrame(civitatis_countries)

civitatis_countries_df.to_csv('C:\\Users\\beder\Desktop\Data 2022\Projects\Activities Implementation\Outputs\Civitatis Exctraction\civitatis_countries.csv',index=False)
